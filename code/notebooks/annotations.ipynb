# %% [markdown]
# # Annotations of the workflow
#
# The idea is to get more content about the project/workflow.
#
# * Conda environment for this Notebook: [Greference_tools](../environments/Greference_tools.yml)

# %%
## Import libreries

# Base packages
import subprocess
import os
import re
# Data manipulation
import pandas as pd
import numpy as np

# %% [markdown]
# # Metadata/report.csv
#
# Lets see our Project and all the fields.
#
# For this project we will be interested in download the Bam files in the ***8 field***: **submitted_ftp**

# %%
report = pd.read_csv("../../metadata/report.tsv", sep="\t")
report
# Out:
#    study_accession sample_accession experiment_accession run_accession  \
# 0        PRJEB7926     SAMEA3168442            ERX641122     ERR696683
# 1        PRJEB7926     SAMEA3168443            ERX697048     ERR753368
# 2        PRJEB7926     SAMEA3168444            ERX697049     ERR753369
# 3        PRJEB7926     SAMEA3168445            ERX697050     ERR753370
# 4        PRJEB7926     SAMEA3168446            ERX697051     ERR753371
# 5        PRJEB7926     SAMEA3168447            ERX697052     ERR753372
# 6        PRJEB7926     SAMEA3168448            ERX697053     ERR753373
# 7        PRJEB7926     SAMEA3168449            ERX697054     ERR753374
# 8        PRJEB7926     SAMEA3168450            ERX697055     ERR753375
# 9        PRJEB7926     SAMEA3168451            ERX697056     ERR753376
# 10       PRJEB7926     SAMEA3168452            ERX697057     ERR753377
# 11       PRJEB7926     SAMEA3168453            ERX697058     ERR753378
#
#     tax_id scientific_name                                          fastq_ftp  \
# 0     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR696/ERR696683/...
# 1     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753368/...
# 2     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753369/...
# 3     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753370/...
# 4     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753371/...
# 5     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753372/...
# 6     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753373/...
# 7     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753374/...
# 8     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753375/...
# 9     9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753376/...
# 10    9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753377/...
# 11    9606    Homo sapiens  ftp.sra.ebi.ac.uk/vol1/fastq/ERR753/ERR753378/...
#
#                                         submitted_ftp  sra_ftp
# 0   ftp.sra.ebi.ac.uk/vol1/run/ERR696/ERR696683/C2...      NaN
# 1   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753368/C2...      NaN
# 2   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753369/C2...      NaN
# 3   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753370/C3...      NaN
# 4   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753371/C3...      NaN
# 5   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753372/C3...      NaN
# 6   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753373/NG...      NaN
# 7   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753374/NG...      NaN
# 8   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753375/C-...      NaN
# 9   ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753376/C2...      NaN
# 10  ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753377/C8...      NaN
# 11  ftp.sra.ebi.ac.uk/vol1/run/ERR753/ERR753378/C3...      NaN

# %% [markdown]
# ## Downloading the table 3, for supporting information found in the article.
#
# After that we will use the function in pandas ```pd.read_clipboard()``` to download the data.
#
# https://onlinelibrary.wiley.com/action/downloadSupplement?doi=10.1002%2Fgcc.22314&file=gcc22314-sup-0005-supptable5.docx

# %%
table3=pd.read_clipboard()
table3.head()
# Out:
#   Sample   Raw Reads Sequencing depth (X) Reads after QC Reads after QC# %  \
# 0  IV-5^  29 191 671                84.95     22 978 888           79,00 %
# 1  IV-2^  40 672 795               122.02     39 920 701           88,00 %
# 2  IV-6^  43 486 476               130.46     38 353 481           88,00 %
# 3  IV-4^  42 838 012               128.51     37 729 408           88,00 %
# 4  IV-7^  377 188 93               113.16     33 250 705           88,00 %
#
#   Mapped reads Reads after QC % % On-target (30X) Mean coverage (X)  \
# 0   45 770 776           99.59%           49,00 %   17.79x(1x-856x)
# 1   71 507 872           99.54%           79,00 %   26.76x(1x-860x)
# 2   76 404 013           99.61%           81,00 %   29.66x(1x-817x)
# 3   75 125 893           99.56%           81,00 %   28.76x(1x-877x)
# 4   66 224 206           99.58%           77,00 %   25.82x(1x-847x)
#
#   Genes covered (%)     SNPs  Indels
# 0            98.48%  114 651   6 935
# 1            99.70%  226 812  10 226
# 2            99.71%  207 627  10 263
# 3            99.91%  229 099  10 325
# 4            99.70%  203 338   9 474

# %%
## We wolud do some tranformations to the first field ("Sample")
table3["Sample"] = table3["Sample"].str.replace(
    "-", "_"
    ).str.replace(
        "^", "_method1"
        ).str.replace(
            "*", "_method2"
            )
table3.head()
# Out:
# /tmp/ipykernel_34176/3769299083.py:4: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ).str.replace(
# /tmp/ipykernel_34176/3769299083.py:6: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   ).str.replace(
#          Sample   Raw Reads Sequencing depth (X) Reads after QC  \
# 0  IV_5_method1  29 191 671                84.95     22 978 888
# 1  IV_2_method1  40 672 795               122.02     39 920 701
# 2  IV_6_method1  43 486 476               130.46     38 353 481
# 3  IV_4_method1  42 838 012               128.51     37 729 408
# 4  IV_7_method1  377 188 93               113.16     33 250 705
#
#   Reads after QC# % Mapped reads Reads after QC % % On-target (30X)  \
# 0           79,00 %   45 770 776           99.59%           49,00 %
# 1           88,00 %   71 507 872           99.54%           79,00 %
# 2           88,00 %   76 404 013           99.61%           81,00 %
# 3           88,00 %   75 125 893           99.56%           81,00 %
# 4           88,00 %   66 224 206           99.58%           77,00 %
#
#   Mean coverage (X) Genes covered (%)     SNPs  Indels
# 0   17.79x(1x-856x)            98.48%  114 651   6 935
# 1   26.76x(1x-860x)            99.70%  226 812  10 226
# 2   29.66x(1x-817x)            99.71%  207 627  10 263
# 3   28.76x(1x-877x)            99.91%  229 099  10 325
# 4   25.82x(1x-847x)            99.70%  203 338   9 474

# %%
table3.to_csv("../metadata/table3.csv", index=None)

# %%
table3_csv = pd.read_csv("../../metadata/table3.csv")
table3_csv
# Out:
#           Sample   Raw Reads Sequencing depth (X) Reads after QC  \
# 0   IV_5_method1  29 191 671                84.95     22 978 888
# 1   IV_2_method1  40 672 795               122.02     39 920 701
# 2   IV_6_method1  43 486 476               130.46     38 353 481
# 3   IV_4_method1  42 838 012               128.51     37 729 408
# 4   IV_7_method1  377 188 93               113.16     33 250 705
# 5    V_8_method1  55 720 364               222.88     51 583 390
# 6    V_2_method1  55 054 777               160.22     37 529 435
# 7    V_1_method1  57 215 132               166.51     34 333 842
# 8   IV_6_method2    43486476               130,46     38 353 481
# 9   IV_2_method2    40672795                122,2       35920701
# 10  IV_4_method2    42838012               125,51       37729408
# 11  IV_7_method2    37718893               113,16       33250705
#
#    Reads after QC# % Mapped reads Reads after QC % % On-target (30X)  \
# 0            79,00 %   45 770 776           99.59%           49,00 %
# 1            88,00 %   71 507 872           99.54%           79,00 %
# 2            88,00 %   76 404 013           99.61%           81,00 %
# 3            88,00 %   75 125 893           99.56%           81,00 %
# 4            88,00 %   66 224 206           99.58%           77,00 %
# 5            93,00 %  102 574 419           99.43%           82,00 %
# 6            68,00 %   74 739 463           99.57%           64,00 %
# 7            60,00 %   68 423 638           99.64%           38,00 %
# 8            88,00 %   76 404 013          99,61 %           81,00 %
# 9            88,00 %   71 507 872          99,54 %           79,00 %
# 10           88,00 %   75 125 893          99,56 %           81,00 %
# 11           88,00 %   66 224 205          99,58 %           77,00 %
#
#    Mean coverage (X) Genes covered (%)     SNPs  Indels
# 0    17.79x(1x-856x)            98.48%  114 651   6 935
# 1    26.76x(1x-860x)            99.70%  226 812  10 226
# 2    29.66x(1x-817x)            99.71%  207 627  10 263
# 3    28.76x(1x-877x)            99.91%  229 099  10 325
# 4    25.82x(1x-847x)            99.70%  203 338   9 474
# 5    49.28x(1x-997x)            99.57%  195 153  12 768
# 6    27.24x(1x-998x)            98.62%  137 021   8 655
# 7    14.35x(1x-885x)            98.21%   99 034   5 679
# 8    29.66x(1x-817x)           99,71 %  207 626  10 263
# 9    26.76x(1x-860x)           99,70 %  226 812  10 226
# 10   28.76x(1x-877x)           99,91 %  229 099  10 325
# 11   25.82x(1x-847x)           99,70 %  203 338   9 474

# %% [markdown]
# ### Amount of reads after removing low quality sequences.
# ### Low quality sequences are considered when
#
# 1. bases with Q20 account for >85% of the total sequence length
# 2. reads with N-rate >10%
#
# ### Methods for seguencing
#
# * **method1** run with Agilent Sureselect XT Human All Exon 50Mb
# * **method2** run with Agilent SureSelect_XT_Human_All_Exon_V5

# %% [markdown]
# ## Mean depth of the project

# %%
table3_csv["Sequencing depth (X)"].str.replace(",",".").astype(float).mean()
# Out:
# 135.00333333333336

# %% [markdown]
# ## **Calculating the AVERAGE sequence length for each sample**

# %%
## heavy computing +25 min -> you need all fastq.gz files in data/raw/

for chr in ["chr3", "chr5", "chr7", "chr12", "chr17"]:
    subprocess.run(["bash", "calculating_length.sh", chr])

subprocess.run(["bash", "joining_files.sh"])
# Out:
# CompletedProcess(args=['bash', 'joining_files.sh'], returncode=0)

# %%
list_files = os.listdir("../../results/annotations/")

list_files_path = []

for file in range(len(list_files)):
    path = "../../results/annotations/" + list_files[file]
    list_files_path.append(path)

# %%
list_mean_len = []
list_sd_len = []

for file_path in list_files_path:

    with open(file_path) as file:
        len_list = file.readlines()
    
    mean_seq_len = np.array([s.strip() for s in len_list]).astype(int).mean().round(2)
    sd_seq_len = np.array([s.strip() for s in len_list]).astype(int).std().round(2)
    
    print("mean value of ", file_path.replace(
        "../../results/annotations/", ""
        ).replace(
            "_len.txt", ""
            ), " -> ", mean_seq_len, "+/-", sd_seq_len)

    list_mean_len.append(mean_seq_len)
    list_sd_len.append(sd_seq_len)
# Out:
# mean value of  ERR753374  ->  94.61 +/- 2.29
# mean value of  ERR753373  ->  94.72 +/- 2.18
# mean value of  ERR753375  ->  75.51 +/- 1.26
# mean value of  ERR753372  ->  75.89 +/- 0.73
# mean value of  ERR753370  ->  100.64 +/- 1.27
# mean value of  ERR696683  ->  75.48 +/- 1.31
# mean value of  ERR753376  ->  75.48 +/- 1.31
# mean value of  ERR753378  ->  75.89 +/- 0.73
# mean value of  ERR753371  ->  75.24 +/- 1.53
# mean value of  ERR753369  ->  75.89 +/- 0.73
# mean value of  ERR753377  ->  75.5 +/- 1.29
# mean value of  ERR753368  ->  75.89 +/- 0.73

# %%
df_len_seq = pd.DataFrame({
    "sample": pd.Series(list_files_path),
    "mean_len": pd.Series(list_mean_len),
    "sd_len": pd.Series(list_sd_len)
})

df_len_seq["sample"] = df_len_seq["sample"].str.replace("../../results/annotations/", "")
df_len_seq["sample"] = df_len_seq["sample"].str.replace("_len.txt", "")

df_len_seq.to_csv("len_mean.csv", index=None)
# Out:
# /tmp/ipykernel_4425/3359814889.py:7: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_len_seq["sample"] = df_len_seq["sample"].str.replace("../../results/annotations/", "")
# /tmp/ipykernel_4425/3359814889.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   df_len_seq["sample"] = df_len_seq["sample"].str.replace("_len.txt", "")

# %%
subprocess.run(["Rscript", "plot_mean_len.R"])
# Out:
# Rows: 12 Columns: 3
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr (1): sample
# dbl (2): mean_len, sd_len
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# CompletedProcess(args=['Rscript', 'plot_mean_len.R'], returncode=0)

# %% [markdown]
# <p align="center">
#
#   <img src="../../results/objective/mean_len.png" alt="800" width="900" />
#
# </p>

# %% [markdown]
# ## **Number of Seqs before and after fastp**

# %%
subprocess.run(["bash", "fastp_analysis.sh"])

# %%
pd.read_csv("fastp_analysis.tsv", sep="\t")
